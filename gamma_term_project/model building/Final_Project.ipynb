# %%
import numpy as np
import pandas as pd
import math
import itertools
import torch

# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')


pd.set_option('display.max_columns', None)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Extract Dataset

# %%
# Define the path to the file
file_path = '/content/drive/MyDrive/Colab Notebooks/ml-1m/cleaned_movies.csv'

movies_df = pd.read_csv(file_path,index_col=0)

movies_df.head()
# Out:
#    movieId                               title  Release_Year  \
# 0        1                    Toy Story (1995)          1995
# 1        2                      Jumanji (1995)          1995
# 2        3             Grumpier Old Men (1995)          1995
# 3        4            Waiting to Exhale (1995)          1995
# 4        5  Father of the Bride Part II (1995)          1995
#
#    Language_Castilian  Language_Chinese  Language_English  Language_Flemish  \
# 0               False             False              True             False
# 1               False             False              True             False
# 2               False             False              True             False
# 3               False             False              True             False
# 4               False             False              True             False
#
#    Language_French  Language_German  Language_Italian  Language_Japanese  \
# 0            False            False             False              False
# 1            False            False             False              False
# 2            False            False             False              False
# 3            False            False             False              False
# 4            False            False             False              False
#
#    Language_Persian  Language_Swedish  Language_others  director_Alan Parker  \
# 0             False             False            False                 False
# 1             False             False            False                 False
# 2             False             False            False                 False
# 3             False             False            False                 False
# 4             False             False            False                 False
#
#    director_Alfred Hitchcock  director_Barry Levinson  director_Billy Wilder  \
# 0                      False                    False                  False
# 1                      False                    False                  False
# 2                      False                    False                  False
# 3                      False                    False                  False
# 4                      False                    False                  False
#
#    director_Charlie Chaplin  director_Clint Eastwood  \
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# 3                     False                    False
# 4                     False                    False
#
#    director_Francis Ford Coppola  director_Joel Schumacher  \
# 0                          False                     False
# 1                          False                     False
# 2                          False                     False
# 3                          False                     False
# 4                          False                     False
#
#    director_John Carpenter  director_Martin Scorsese  director_Richard Donner  \
# 0                    False                     False                    False
# 1                    False                     False                    False
# 2                    False                     False                    False
# 3                    False                     False                    False
# 4                    False                     False                    False
#
#    director_Rob Reiner  director_Robert Altman  director_Robert Stevenson  \
# 0                False                   False                      False
# 1                False                   False                      False
# 2                False                   False                      False
# 3                False                   False                      False
# 4                False                   False                      False
#
#    director_Ron Howard  director_Sidney Lumet  director_Spike Lee  \
# 0                False                  False               False
# 1                False                  False               False
# 2                False                  False               False
# 3                False                  False               False
# 4                False                  False               False
#
#    director_Stanley Kubrick  director_Steven Spielberg  director_Woody Allen  \
# 0                     False                      False                 False
# 1                     False                      False                 False
# 2                     False                      False                 False
# 3                     False                      False                 False
# 4                     False                      False                 False
#
#    director_others  Genre_Drama  Genre_Comedy  Genre_Action  Genre_Thriller  \
# 0             True        False          True         False           False
# 1             True        False         False         False           False
# 2             True        False          True         False           False
# 3             True         True          True         False           False
# 4             True        False          True         False           False
#
#    Genre_Romance  Genre_Horror  Genre_Adventure  Genre_Sci-Fi  \
# 0          False         False            False         False
# 1          False         False             True         False
# 2           True         False            False         False
# 3          False         False            False         False
# 4          False         False            False         False
#
#    Genre_Children's  Genre_Crime  Star_robert de niro  Star_whoopi goldberg  \
# 0              True        False                False                 False
# 1              True        False                False                 False
# 2             False        False                False                 False
# 3             False        False                False                 False
# 4             False        False                False                 False
#
#    Star_harvey keitel  Star_bruce willis  Star_robert duvall  \
# 0               False              False               False
# 1               False              False               False
# 2               False              False               False
# 3               False              False               False
# 4               False              False               False
#
#    Star_gene hackman  Star_jack nicholson  Star_samuel l jackson  \
# 0              False                False                  False
# 1              False                False                  False
# 2              False                False                  False
# 3              False                False                  False
# 4              False                False                  False
#
#    Star_sean connery  Star_demi moore  Star_robin williams  \
# 0              False            False                False
# 1              False            False                 True
# 2              False            False                False
# 3              False            False                False
# 4              False            False                False
#
#    Star_dennis hopper  Star_mel gibson  Star_jeff bridges  \
# 0               False            False              False
# 1               False            False              False
# 2               False            False              False
# 3               False            False              False
# 4               False            False              False
#
#    Star_michelle pfeiffer  Star_dan aykroyd  Star_harrison ford  \
# 0                   False             False               False
# 1                   False             False               False
# 2                   False             False               False
# 3                   False             False               False
# 4                   False             False               False
#
#    Star_joan cusack  Star_john cusack  Star_clint eastwood  \
# 0             False             False                False
# 1             False             False                False
# 2             False             False                False
# 3             False             False                False
# 4             False             False                False
#
#    Keyword_based on novel or book  Keyword_woman director  \
# 0                           False                   False
# 1                           False                   False
# 2                           False                   False
# 3                            True                   False
# 4                           False                   False
#
#    Keyword_new york city  Keyword_murder  Keyword_california  \
# 0                  False           False               False
# 1                  False           False               False
# 2                  False           False               False
# 3                  False           False               False
# 4                  False           False                True
#
#    Keyword_black and white  Keyword_england  Keyword_musical  Keyword_sequel  \
# 0                    False            False            False           False
# 1                    False            False            False           False
# 2                    False            False            False            True
# 3                    False            False            False           False
# 4                    False            False            False            True
#
#    Keyword_revenge  Keyword_los angeles  Keyword_gay theme  Keyword_love  \
# 0            False                False              False         False
# 1            False                False              False         False
# 2            False                False              False         False
# 3            False                False              False         False
# 4            False                 True              False         False
#
#    Keyword_police  Keyword_based on play or musical  Keyword_friendship  \
# 0           False                             False                True
# 1           False                             False               False
# 2           False                             False               False
# 3           False                             False               False
# 4           False                             False               False
#
#    Keyword_sports  Keyword_france  Keyword_parent child relationship  \
# 0           False           False                              False
# 1           False           False                              False
# 2           False           False                              False
# 3           False           False                              False
# 4           False           False                               True
#
#    Keyword_serial killer
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %%
movies_df.isnull().sum()
# Out:
# movieId                              0
# title                                0
# Release_Year                         0
# Language_Castilian                   0
# Language_Chinese                     0
#                                     ..
# Keyword_friendship                   0
# Keyword_sports                       0
# Keyword_france                       0
# Keyword_parent child relationship    0
# Keyword_serial killer                0
# Length: 85, dtype: int64

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/ml-1m/users.dat'

# Define the column names
column_names = ['UserID', 'Gender', 'Age', 'Occupation', 'Zip-code']

# Read the file into a DataFrame
users_df = pd.read_csv(file_path, sep='::', names=column_names, engine='python')

users_df.head()
# Out:
#    UserID Gender  Age  Occupation Zip-code
# 0       1      F    1          10    48067
# 1       2      M   56          16    70072
# 2       3      M   25          15    55117
# 3       4      M   45           7    02460
# 4       5      M   25          20    55455

# %%
users_df.isnull().sum()
# Out:
# UserID        0
# Gender        0
# Age           0
# Occupation    0
# Zip-code      0
# dtype: int64

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/ml-1m/ratings.dat'

# Define the column names
column_names = ['UserID', 'MovieID', 'Rating', 'Timestamp']

# Read the file into a DataFrame
ratings_df = pd.read_csv(file_path, sep='::', names=column_names, engine='python')

# Convert the Timestamp column to datetime
ratings_df['Timestamp'] = pd.to_datetime(ratings_df['Timestamp'], unit='s')

# remove records that the movieid or userid has no details
ratings_df = ratings_df[ratings_df['MovieID'].isin(list(movies_df['movieId'].unique()))]
ratings_df = ratings_df[ratings_df['UserID'].isin(list(users_df['UserID'].unique()))]

# Display the first few rows of the DataFrame
ratings_df.head()
# Out:
#    UserID  MovieID  Rating           Timestamp
# 0       1     1193       5 2000-12-31 22:12:40
# 1       1      661       3 2000-12-31 22:35:09
# 2       1      914       3 2000-12-31 22:32:48
# 3       1     3408       4 2000-12-31 22:04:35
# 4       1     2355       5 2001-01-06 23:38:11

# %%
ratings_df.isnull().sum()
# Out:
# UserID       0
# MovieID      0
# Rating       0
# Timestamp    0
# dtype: int64

# %%
# !pip3 install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.3.0+cu121.html
# !pip3 install torch_geometric

# %%
import torch
import torch.nn.functional as F
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from torch_geometric.data import HeteroData
from torch_geometric.transforms import ToUndirected, RandomLinkSplit
from transformers import BertTokenizer, BertModel
import torch.optim as optim
from torch_geometric.loader import LinkNeighborLoader
from torch_geometric.nn import SAGEConv, to_hetero
from torch import Tensor
from torch_geometric.data import HeteroData

# %% [markdown]
# # 2. Preprocess Data

# %%
# !pip3 install pyzipcode

# %%
# One-hot encode Gender and Occupation
users_df = pd.get_dummies(users_df, columns=['Gender', 'Occupation'], drop_first=True)

# # Standardize Age
# scaler = StandardScaler()
# users_df[['Age']] = scaler.fit_transform(users_df[['Age']])


# Convert Zipcode to State and One-Hot encode State
from pyzipcode import ZipCodeDatabase

def zipcode_converter(zipcode):
    zcdb = ZipCodeDatabase()
    try:
        return zcdb[int(zipcode)].state
    except:
        return 'None'


users_df['State'] = users_df['Zip-code'].apply(lambda x: zipcode_converter(x))
users_df = pd.get_dummies(users_df, columns=['State'], drop_first=True)

# Drop UserID and original Zip-code columns
users_df = users_df.drop(columns=['UserID', 'Zip-code'])

users_df
# Out:
#       Age  Gender_M  Occupation_1  Occupation_2  Occupation_3  Occupation_4  \
# 0       1     False         False         False         False         False
# 1      56      True         False         False         False         False
# 2      25      True         False         False         False         False
# 3      45      True         False         False         False         False
# 4      25      True         False         False         False         False
# ...   ...       ...           ...           ...           ...           ...
# 6035   25     False         False         False         False         False
# 6036   45     False          True         False         False         False
# 6037   56     False          True         False         False         False
# 6038   45     False         False         False         False         False
# 6039   25      True         False         False         False         False
#
#       Occupation_5  Occupation_6  Occupation_7  Occupation_8  Occupation_9  \
# 0            False         False         False         False         False
# 1            False         False         False         False         False
# 2            False         False         False         False         False
# 3            False         False          True         False         False
# 4            False         False         False         False         False
# ...            ...           ...           ...           ...           ...
# 6035         False         False         False         False         False
# 6036         False         False         False         False         False
# 6037         False         False         False         False         False
# 6038         False         False         False         False         False
# 6039         False          True         False         False         False
#
#       Occupation_10  Occupation_11  Occupation_12  Occupation_13  \
# 0              True          False          False          False
# 1             False          False          False          False
# 2             False          False          False          False
# 3             False          False          False          False
# 4             False          False          False          False
# ...             ...            ...            ...            ...
# 6035          False          False          False          False
# 6036          False          False          False          False
# 6037          False          False          False          False
# 6038          False          False          False          False
# 6039          False          False          False          False
#
#       Occupation_14  Occupation_15  Occupation_16  Occupation_17  \
# 0             False          False          False          False
# 1             False          False           True          False
# 2             False           True          False          False
# 3             False          False          False          False
# 4             False          False          False          False
# ...             ...            ...            ...            ...
# 6035          False           True          False          False
# 6036          False          False          False          False
# 6037          False          False          False          False
# 6038          False          False          False          False
# 6039          False          False          False          False
#
#       Occupation_18  Occupation_19  Occupation_20  State_AL  State_AR  \
# 0             False          False          False     False     False
# 1             False          False          False     False     False
# 2             False          False          False     False     False
# 3             False          False          False     False     False
# 4             False          False           True     False     False
# ...             ...            ...            ...       ...       ...
# 6035          False          False          False     False     False
# 6036          False          False          False     False     False
# 6037          False          False          False     False     False
# 6038          False          False          False     False     False
# 6039          False          False          False     False     False
#
#       State_AZ  State_CA  State_CO  State_CT  State_DC  State_DE  State_FL  \
# 0        False     False     False     False     False     False     False
# 1        False     False     False     False     False     False     False
# 2        False     False     False     False     False     False     False
# 3        False     False     False     False     False     False     False
# 4        False     False     False     False     False     False     False
# ...        ...       ...       ...       ...       ...       ...       ...
# 6035     False     False     False     False     False     False      True
# 6036     False     False     False     False     False     False     False
# 6037     False     False     False     False     False     False     False
# 6038     False     False     False     False     False     False     False
# 6039     False     False     False     False     False     False     False
#
#       State_GA  State_HI  State_IA  State_ID  State_IL  State_IN  State_KS  \
# 0        False     False     False     False     False     False     False
# 1        False     False     False     False     False     False     False
# 2        False     False     False     False     False     False     False
# 3        False     False     False     False     False     False     False
# 4        False     False     False     False     False     False     False
# ...        ...       ...       ...       ...       ...       ...       ...
# 6035     False     False     False     False     False     False     False
# 6036     False     False     False     False     False     False     False
# 6037     False     False     False     False     False     False     False
# 6038     False     False     False     False     False     False     False
# 6039     False     False     False     False     False     False     False
#
#       State_KY  State_LA  State_MA  State_MD  State_ME  State_MI  State_MN  \
# 0        False     False     False     False     False      True     False
# 1        False      True     False     False     False     False     False
# 2        False     False     False     False     False     False      True
# 3        False     False      True     False     False     False     False
# 4        False     False     False     False     False     False      True
# ...        ...       ...       ...       ...       ...       ...       ...
# 6035     False     False     False     False     False     False     False
# 6036     False     False     False     False     False     False     False
# 6037     False     False     False     False     False     False     False
# 6038     False     False      True     False     False     False     False
# 6039     False     False     False     False     False     False     False
#
#       State_MO  State_MS  State_MT  State_NC  State_ND  State_NE  State_NH  \
# 0        False     False     False     False     False     False     False
# 1        False     False     False     False     False     False     False
# 2        False     False     False     False     False     False     False
# 3        False     False     False     False     False     False     False
# 4        False     False     False     False     False     False     False
# ...        ...       ...       ...       ...       ...       ...       ...
# 6035     False     False     False     False     False     False     False
# 6036     False     False     False     False     False     False     False
# 6037     False     False     False     False     False     False     False
# 6038     False     False     False     False     False     False     False
# 6039     False     False     False     False     False     False     False
#
#       State_NJ  State_NM  State_NV  State_NY  State_None  State_OH  State_OK  \
# 0        False     False     False     False       False     False     False
# 1        False     False     False     False       False     False     False
# 2        False     False     False     False       False     False     False
# 3        False     False     False     False       False     False     False
# 4        False     False     False     False       False     False     False
# ...        ...       ...       ...       ...         ...       ...       ...
# 6035     False     False     False     False       False     False     False
# 6036     False     False     False     False       False     False     False
# 6037     False     False     False      True       False     False     False
# 6038     False     False     False     False       False     False     False
# 6039     False     False     False      True       False     False     False
#
#       State_OR  State_PA  State_PR  State_RI  State_SC  State_SD  State_TN  \
# 0        False     False     False     False     False     False     False
# 1        False     False     False     False     False     False     False
# 2        False     False     False     False     False     False     False
# 3        False     False     False     False     False     False     False
# 4        False     False     False     False     False     False     False
# ...        ...       ...       ...       ...       ...       ...       ...
# 6035     False     False     False     False     False     False     False
# 6036     False     False     False     False     False     False     False
# 6037     False     False     False     False     False     False     False
# 6038     False     False     False     False     False     False     False
# 6039     False     False     False     False     False     False     False
#
#       State_TX  State_UT  State_VA  State_VT  State_WA  State_WI  State_WV  \
# 0        False     False     False     False     False     False     False
# 1        False     False     False     False     False     False     False
# 2        False     False     False     False     False     False     False
# 3        False     False     False     False     False     False     False
# 4        False     False     False     False     False     False     False
# ...        ...       ...       ...       ...       ...       ...       ...
# 6035     False     False     False     False     False     False     False
# 6036      True     False     False     False     False     False     False
# 6037     False     False     False     False     False     False     False
# 6038     False     False     False     False     False     False     False
# 6039     False     False     False     False     False     False     False
#
#       State_WY
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 6035     False
# 6036     False
# 6037     False
# 6038     False
# 6039     False
#
# [6040 rows x 74 columns]

# %%
users_df.columns
# Out:
# Index(['Age', 'Gender_M', 'Occupation_1', 'Occupation_2', 'Occupation_3',
#        'Occupation_4', 'Occupation_5', 'Occupation_6', 'Occupation_7',
#        'Occupation_8', 'Occupation_9', 'Occupation_10', 'Occupation_11',
#        'Occupation_12', 'Occupation_13', 'Occupation_14', 'Occupation_15',
#        'Occupation_16', 'Occupation_17', 'Occupation_18', 'Occupation_19',
#        'Occupation_20', 'State_AL', 'State_AR', 'State_AZ', 'State_CA',
#        'State_CO', 'State_CT', 'State_DC', 'State_DE', 'State_FL', 'State_GA',
#        'State_HI', 'State_IA', 'State_ID', 'State_IL', 'State_IN', 'State_KS',
#        'State_KY', 'State_LA', 'State_MA', 'State_MD', 'State_ME', 'State_MI',
#        'State_MN', 'State_MO', 'State_MS', 'State_MT', 'State_NC', 'State_ND',
#        'State_NE', 'State_NH', 'State_NJ', 'State_NM', 'State_NV', 'State_NY',
#        'State_None', 'State_OH', 'State_OK', 'State_OR', 'State_PA',
#        'State_PR', 'State_RI', 'State_SC', 'State_SD', 'State_TN', 'State_TX',
#        'State_UT', 'State_VA', 'State_VT', 'State_WA', 'State_WI', 'State_WV',
#        'State_WY'],
#       dtype='object')

# %%
#convert pandas dataframe to tensor
user_features = torch.tensor(users_df.values.astype('float32'), dtype=torch.float32)

# %%
# Extract movie features (excluding MovieID, Title)
movie_features = movies_df.drop(columns=['movieId', 'title'])

movie_features
# Out:
#       Release_Year  Language_Castilian  Language_Chinese  Language_English  \
# 0             1995               False             False              True
# 1             1995               False             False              True
# 2             1995               False             False              True
# 3             1995               False             False              True
# 4             1995               False             False              True
# ...            ...                 ...               ...               ...
# 3877          1971               False             False              True
# 3878          2000               False             False              True
# 3879          2000               False             False              True
# 3880          2000               False             False              True
# 3882          2000               False             False              True
#
#       Language_Flemish  Language_French  Language_German  Language_Italian  \
# 0                False            False            False             False
# 1                False            False            False             False
# 2                False            False            False             False
# 3                False            False            False             False
# 4                False            False            False             False
# ...                ...              ...              ...               ...
# 3877             False            False            False             False
# 3878             False            False            False             False
# 3879             False            False            False             False
# 3880             False            False            False             False
# 3882             False            False            False             False
#
#       Language_Japanese  Language_Persian  Language_Swedish  Language_others  \
# 0                 False             False             False            False
# 1                 False             False             False            False
# 2                 False             False             False            False
# 3                 False             False             False            False
# 4                 False             False             False            False
# ...                 ...               ...               ...              ...
# 3877              False             False             False            False
# 3878              False             False             False            False
# 3879              False             False             False            False
# 3880              False             False             False            False
# 3882              False             False             False            False
#
#       director_Alan Parker  director_Alfred Hitchcock  \
# 0                    False                      False
# 1                    False                      False
# 2                    False                      False
# 3                    False                      False
# 4                    False                      False
# ...                    ...                        ...
# 3877                 False                      False
# 3878                 False                      False
# 3879                 False                      False
# 3880                 False                      False
# 3882                 False                      False
#
#       director_Barry Levinson  director_Billy Wilder  \
# 0                       False                  False
# 1                       False                  False
# 2                       False                  False
# 3                       False                  False
# 4                       False                  False
# ...                       ...                    ...
# 3877                    False                  False
# 3878                    False                  False
# 3879                    False                  False
# 3880                    False                  False
# 3882                    False                  False
#
#       director_Charlie Chaplin  director_Clint Eastwood  \
# 0                        False                    False
# 1                        False                    False
# 2                        False                    False
# 3                        False                    False
# 4                        False                    False
# ...                        ...                      ...
# 3877                     False                    False
# 3878                     False                    False
# 3879                     False                    False
# 3880                     False                    False
# 3882                     False                    False
#
#       director_Francis Ford Coppola  director_Joel Schumacher  \
# 0                             False                     False
# 1                             False                     False
# 2                             False                     False
# 3                             False                     False
# 4                             False                     False
# ...                             ...                       ...
# 3877                          False                     False
# 3878                          False                     False
# 3879                          False                     False
# 3880                          False                      True
# 3882                          False                     False
#
#       director_John Carpenter  director_Martin Scorsese  \
# 0                       False                     False
# 1                       False                     False
# 2                       False                     False
# 3                       False                     False
# 4                       False                     False
# ...                       ...                       ...
# 3877                    False                     False
# 3878                    False                     False
# 3879                    False                     False
# 3880                    False                     False
# 3882                    False                     False
#
#       director_Richard Donner  director_Rob Reiner  director_Robert Altman  \
# 0                       False                False                   False
# 1                       False                False                   False
# 2                       False                False                   False
# 3                       False                False                   False
# 4                       False                False                   False
# ...                       ...                  ...                     ...
# 3877                    False                False                   False
# 3878                    False                False                   False
# 3879                    False                False                   False
# 3880                    False                False                   False
# 3882                    False                False                   False
#
#       director_Robert Stevenson  director_Ron Howard  director_Sidney Lumet  \
# 0                         False                False                  False
# 1                         False                False                  False
# 2                         False                False                  False
# 3                         False                False                  False
# 4                         False                False                  False
# ...                         ...                  ...                    ...
# 3877                      False                False                  False
# 3878                      False                False                  False
# 3879                      False                False                  False
# 3880                      False                False                  False
# 3882                      False                False                  False
#
#       director_Spike Lee  director_Stanley Kubrick  director_Steven Spielberg  \
# 0                  False                     False                      False
# 1                  False                     False                      False
# 2                  False                     False                      False
# 3                  False                     False                      False
# 4                  False                     False                      False
# ...                  ...                       ...                        ...
# 3877               False                     False                      False
# 3878               False                     False                      False
# 3879               False                     False                      False
# 3880               False                     False                      False
# 3882               False                     False                      False
#
#       director_Woody Allen  director_others  Genre_Drama  Genre_Comedy  \
# 0                    False             True        False          True
# 1                    False             True        False         False
# 2                    False             True        False          True
# 3                    False             True         True          True
# 4                    False             True        False          True
# ...                    ...              ...          ...           ...
# 3877                 False             True        False         False
# 3878                 False             True        False          True
# 3879                 False             True         True         False
# 3880                 False            False         True         False
# 3882                 False             True         True         False
#
#       Genre_Action  Genre_Thriller  Genre_Romance  Genre_Horror  \
# 0            False           False          False         False
# 1            False           False          False         False
# 2            False           False           True         False
# 3            False           False          False         False
# 4            False           False          False         False
# ...            ...             ...            ...           ...
# 3877         False            True          False         False
# 3878         False           False          False         False
# 3879         False           False          False         False
# 3880         False           False          False         False
# 3882         False            True          False         False
#
#       Genre_Adventure  Genre_Sci-Fi  Genre_Children's  Genre_Crime  \
# 0               False         False              True        False
# 1                True         False              True        False
# 2               False         False             False        False
# 3               False         False             False        False
# 4               False         False             False        False
# ...               ...           ...               ...          ...
# 3877            False         False             False        False
# 3878            False         False             False        False
# 3879            False         False             False        False
# 3880            False         False             False        False
# 3882            False         False             False        False
#
#       Star_robert de niro  Star_whoopi goldberg  Star_harvey keitel  \
# 0                   False                 False               False
# 1                   False                 False               False
# 2                   False                 False               False
# 3                   False                 False               False
# 4                   False                 False               False
# ...                   ...                   ...                 ...
# 3877                False                 False               False
# 3878                 True                 False               False
# 3879                False                 False               False
# 3880                False                 False               False
# 3882                False                 False               False
#
#       Star_bruce willis  Star_robert duvall  Star_gene hackman  \
# 0                 False               False              False
# 1                 False               False              False
# 2                 False               False              False
# 3                 False               False              False
# 4                 False               False              False
# ...                 ...                 ...                ...
# 3877              False               False              False
# 3878              False               False              False
# 3879              False               False              False
# 3880              False               False              False
# 3882              False               False              False
#
#       Star_jack nicholson  Star_samuel l jackson  Star_sean connery  \
# 0                   False                  False              False
# 1                   False                  False              False
# 2                   False                  False              False
# 3                   False                  False              False
# 4                   False                  False              False
# ...                   ...                    ...                ...
# 3877                False                  False              False
# 3878                False                  False              False
# 3879                False                  False              False
# 3880                False                  False              False
# 3882                False                  False              False
#
#       Star_demi moore  Star_robin williams  Star_dennis hopper  \
# 0               False                False               False
# 1               False                 True               False
# 2               False                False               False
# 3               False                False               False
# 4               False                False               False
# ...               ...                  ...                 ...
# 3877            False                False               False
# 3878            False                False               False
# 3879            False                False               False
# 3880            False                False               False
# 3882            False                False               False
#
#       Star_mel gibson  Star_jeff bridges  Star_michelle pfeiffer  \
# 0               False              False                   False
# 1               False              False                   False
# 2               False              False                   False
# 3               False              False                   False
# 4               False              False                   False
# ...               ...                ...                     ...
# 3877            False              False                   False
# 3878            False              False                   False
# 3879            False              False                   False
# 3880            False              False                   False
# 3882            False               True                   False
#
#       Star_dan aykroyd  Star_harrison ford  Star_joan cusack  \
# 0                False               False             False
# 1                False               False             False
# 2                False               False             False
# 3                False               False             False
# 4                False               False             False
# ...                ...                 ...               ...
# 3877             False               False             False
# 3878             False               False             False
# 3879             False               False             False
# 3880             False               False             False
# 3882             False               False             False
#
#       Star_john cusack  Star_clint eastwood  Keyword_based on novel or book  \
# 0                False                False                           False
# 1                False                False                           False
# 2                False                False                           False
# 3                False                False                            True
# 4                False                False                           False
# ...                ...                  ...                             ...
# 3877             False                False                           False
# 3878             False                False                           False
# 3879             False                False                           False
# 3880             False                False                           False
# 3882             False                False                           False
#
#       Keyword_woman director  Keyword_new york city  Keyword_murder  \
# 0                      False                  False           False
# 1                      False                  False           False
# 2                      False                  False           False
# 3                      False                  False           False
# 4                      False                  False           False
# ...                      ...                    ...             ...
# 3877                   False                  False           False
# 3878                   False                  False           False
# 3879                   False                  False           False
# 3880                   False                  False           False
# 3882                   False                  False           False
#
#       Keyword_california  Keyword_black and white  Keyword_england  \
# 0                  False                    False            False
# 1                  False                    False            False
# 2                  False                    False            False
# 3                  False                    False            False
# 4                   True                    False            False
# ...                  ...                      ...              ...
# 3877               False                    False            False
# 3878               False                    False            False
# 3879               False                    False            False
# 3880               False                    False            False
# 3882               False                    False            False
#
#       Keyword_musical  Keyword_sequel  Keyword_revenge  Keyword_los angeles  \
# 0               False           False            False                False
# 1               False           False            False                False
# 2               False            True            False                False
# 3               False           False            False                False
# 4               False            True            False                 True
# ...               ...             ...              ...                  ...
# 3877            False           False            False                False
# 3878            False           False            False                False
# 3879            False           False            False                False
# 3880            False           False            False                False
# 3882            False           False            False                False
#
#       Keyword_gay theme  Keyword_love  Keyword_police  \
# 0                 False         False           False
# 1                 False         False           False
# 2                 False         False           False
# 3                 False         False           False
# 4                 False         False           False
# ...                 ...           ...             ...
# 3877              False         False           False
# 3878              False         False           False
# 3879               True         False           False
# 3880              False         False           False
# 3882              False         False           False
#
#       Keyword_based on play or musical  Keyword_friendship  Keyword_sports  \
# 0                                False                True           False
# 1                                False               False           False
# 2                                False               False           False
# 3                                False               False           False
# 4                                False               False           False
# ...                                ...                 ...             ...
# 3877                             False               False           False
# 3878                             False               False           False
# 3879                             False               False           False
# 3880                             False               False           False
# 3882                             False               False           False
#
#       Keyword_france  Keyword_parent child relationship  Keyword_serial killer
# 0              False                              False                  False
# 1              False                              False                  False
# 2              False                              False                  False
# 3              False                              False                  False
# 4              False                               True                  False
# ...              ...                                ...                    ...
# 3877           False                              False                  False
# 3878           False                              False                  False
# 3879           False                              False                  False
# 3880           False                              False                  False
# 3882           False                              False                  False
#
# [3435 rows x 83 columns]

# %%
movie_features.columns
# Out:
# Index(['Release_Year', 'Language_Castilian', 'Language_Chinese',
#        'Language_English', 'Language_Flemish', 'Language_French',
#        'Language_German', 'Language_Italian', 'Language_Japanese',
#        'Language_Persian', 'Language_Swedish', 'Language_others',
#        'director_Alan Parker', 'director_Alfred Hitchcock',
#        'director_Barry Levinson', 'director_Billy Wilder',
#        'director_Charlie Chaplin', 'director_Clint Eastwood',
#        'director_Francis Ford Coppola', 'director_Joel Schumacher',
#        'director_John Carpenter', 'director_Martin Scorsese',
#        'director_Richard Donner', 'director_Rob Reiner',
#        'director_Robert Altman', 'director_Robert Stevenson',
#        'director_Ron Howard', 'director_Sidney Lumet', 'director_Spike Lee',
#        'director_Stanley Kubrick', 'director_Steven Spielberg',
#        'director_Woody Allen', 'director_others', 'Genre_Drama',
#        'Genre_Comedy', 'Genre_Action', 'Genre_Thriller', 'Genre_Romance',
#        'Genre_Horror', 'Genre_Adventure', 'Genre_Sci-Fi', 'Genre_Children's',
#        'Genre_Crime', 'Star_robert de niro', 'Star_whoopi goldberg',
#        'Star_harvey keitel', 'Star_bruce willis', 'Star_robert duvall',
#        'Star_gene hackman', 'Star_jack nicholson', 'Star_samuel l jackson',
#        'Star_sean connery', 'Star_demi moore', 'Star_robin williams',
#        'Star_dennis hopper', 'Star_mel gibson', 'Star_jeff bridges',
#        'Star_michelle pfeiffer', 'Star_dan aykroyd', 'Star_harrison ford',
#        'Star_joan cusack', 'Star_john cusack', 'Star_clint eastwood',
#        'Keyword_based on novel or book', 'Keyword_woman director',
#        'Keyword_new york city', 'Keyword_murder', 'Keyword_california',
#        'Keyword_black and white', 'Keyword_england', 'Keyword_musical',
#        'Keyword_sequel', 'Keyword_revenge', 'Keyword_los angeles',
#        'Keyword_gay theme', 'Keyword_love', 'Keyword_police',
#        'Keyword_based on play or musical', 'Keyword_friendship',
#        'Keyword_sports', 'Keyword_france', 'Keyword_parent child relationship',
#        'Keyword_serial killer'],
#       dtype='object')

# %%
#convert pandas dataframe to tensor
movie_features = torch.tensor(movie_features.values.astype('float32'), dtype=torch.float32)

# %% [markdown]
# # 3. Construct Graph Data

# %%
user_mapping = {idx: i for i, idx in enumerate(ratings_df['UserID'].unique())}
movie_mapping = {idx: i for i, idx in enumerate(ratings_df['MovieID'].unique())}

# %%
src = [user_mapping[idx] for idx in ratings_df['UserID']]
dst = [movie_mapping[idx] for idx in ratings_df['MovieID']]
edge_index = torch.tensor([src, dst])
edge_label = torch.from_numpy(ratings_df['Rating'].values).to(torch.long)

# %%
data = HeteroData()
# Save node indices:
data["user"].node_id = torch.arange(len(set(src)))
data["movie"].node_id = torch.arange(len(movies_df))
# Add the node features and edge indices:
data["user"].x = user_features
data["movie"].x = movie_features
data["user", "rates", "movie"].edge_index = edge_index
data["user", "rates", "movie"].edge_label = edge_label
# We also need to make sure to add the reverse edges from movies to users
# in order to let a GNN be able to pass messages in both directions.
# We can leverage the `T.ToUndirected()` transform for this from PyG:
data = ToUndirected()(data)

# %%
data
# Out:
# HeteroData(
#   user={
#     node_id=[6040],
#     x=[6040, 74],
#   },
#   movie={
#     node_id=[3435],
#     x=[3435, 83],
#   },
#   (user, rates, movie)={
#     edge_index=[2, 976271],
#     edge_label=[976271],
#   },
#   (movie, rev_rates, user)={
#     edge_index=[2, 976271],
#     edge_label=[976271],
#   }
# )

# %% [markdown]
# # 4. Train & Optimze Model

# %%
# training (80%), validation (10%), and testing edges (10%).
# For this, we first split the set of edges into
# Across the training edges, we use 70% of edges for message passing, and 30% of edges for supervision.
# We further want to generate fixed negative edges for evaluation with a ratio of 2:1 negative edges during training will be generated on-the-fly.
# We can leverage the `RandomLinkSplit()` transform for this from PyG:
transform = RandomLinkSplit(
    num_val=0.1,
    num_test=0.1,
    disjoint_train_ratio=0.3,
    neg_sampling_ratio=2.0,
    add_negative_train_samples=False,
    edge_types=("user", "rates", "movie"),
    rev_edge_types=("movie", "rev_rates", "user"),
)
train_data, val_data, test_data = transform(data)

# %%
# We have an unbalanced dataset with many labels for rating 3 and 4, and very few for 0 and 1. Therefore we use a weighted MSE loss.
# Count the frequency of each value in an array of non-negative ints: https://pytorch.org/docs/stable/generated/torch.bincount.html
weight = torch.bincount(train_data['user', 'movie'].edge_label)
# Take the maximum number of appearences of a rate and normalize all with that number
weight = weight.max() / weight

# %%
def weighted_mse_loss(pred, target, weight=None):
    weight = 1. if weight is None else weight[target].to(pred.dtype)
    return (weight * (pred - target.to(pred.dtype)).pow(2)).mean()

# %%
from torch.nn import Linear

class GNNEncoder(torch.nn.Module):
    def __init__(self, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = SAGEConv((-1, -1), hidden_channels)
        self.conv2 = SAGEConv((-1, -1), out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        x = self.conv2(x, edge_index)
        return x


class EdgeDecoder(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.lin1 = Linear(2 * hidden_channels, hidden_channels)
        self.lin2 = Linear(hidden_channels, 1)

    def forward(self, z_dict, edge_label_index):
        row, col = edge_label_index
        z = torch.cat([z_dict['user'][row], z_dict['movie'][col]], dim=-1)

        z = self.lin1(z).relu()
        z = self.lin2(z)
        return z.view(-1)


class Model(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.encoder = GNNEncoder(hidden_channels, hidden_channels)
        self.encoder = to_hetero(self.encoder, data.metadata(), aggr='sum')
        self.decoder = EdgeDecoder(hidden_channels)

    def forward(self, x_dict, edge_index_dict, edge_label_index):
        z_dict = self.encoder(x_dict, edge_index_dict)
        return self.decoder(z_dict, edge_label_index)


model = Model(hidden_channels=32)

# %%
# run one model step so the numberof parameters can be inferred:
with torch.no_grad():
    model.encoder(train_data.x_dict, train_data.edge_index_dict)

optimizer = torch.optim.Adam(model.parameters(), lr=0.1)

# %%
def train():
    model.train()
    optimizer.zero_grad()

    '''
    train_data.x_dict = diccionario que contiene los embeddings iniciales tanto de los usuarios como de las peliculas
    train_data.edge_index_dict = diccionario que contiene las conexiones entre los nodos (contiene los tipos de conexiones)
    train_data['user', 'movie'].edge_label_index = diccionario que contiene las conexiones entre los nodos (contiene los tipos de conexiones)
    '''

    pred = model(train_data.x_dict, train_data.edge_index_dict, train_data['user', 'movie'].edge_label_index)
    target = train_data['user', 'movie'].edge_label

    loss = weighted_mse_loss(pred, target, weight)
    loss.backward()
    optimizer.step()
    return float(loss)

# %%
def train_model(data):
    model.eval()
    pred = model(data.x_dict, data.edge_index_dict, data['user', 'movie'].edge_label_index)
    pred = pred.clamp(min=0, max=5)
    target = data['user', 'movie'].edge_label.float()
    rmse = F.mse_loss(pred, target).sqrt()

    return float(rmse)

# %%
from sklearn.metrics import roc_auc_score

no_improvement = 0
patience = 10
best_train_rmse = 100

for epoch in range(1, 50):
    loss = train()
    train_rmse = train_model(train_data)
    val_rmse = train_model(val_data)

    print(f'Epoch: {epoch:03d}, Loss: {loss:.3f}, Train RMSE: {train_rmse:.3f}, Val RMSE: {val_rmse:.3f}')


    # if train_rmse < best_train_rmse:
    #     best_train_rmse = train_rmse
    #     no_improvement = 0
    # else:
    #     no_improvement += 1

    # # Check if we need to stop training
    # if no_improvement >= patience:
    #     print(f'Early stopping at epoch {epoch+1} as validation loss did not improve for {patience} consecutive epochs.')
    #     break
# Out:
# Epoch: 001, Loss: 6.408, Train RMSE: 1.629, Val RMSE: 2.418
# Epoch: 002, Loss: 4.111, Train RMSE: 1.121, Val RMSE: 3.110
# Epoch: 003, Loss: 4.264, Train RMSE: 1.263, Val RMSE: 3.475
# Epoch: 004, Loss: 5.872, Train RMSE: 1.135, Val RMSE: 2.920
# Epoch: 005, Loss: 3.738, Train RMSE: 1.748, Val RMSE: 2.365
# Epoch: 006, Loss: 4.488, Train RMSE: 1.901, Val RMSE: 2.315
# Epoch: 007, Loss: 5.066, Train RMSE: 1.276, Val RMSE: 2.676
# Epoch: 008, Loss: 3.484, Train RMSE: 1.154, Val RMSE: 3.251
# Epoch: 009, Loss: 4.800, Train RMSE: 1.119, Val RMSE: 3.092
# Epoch: 010, Loss: 4.203, Train RMSE: 1.462, Val RMSE: 2.515
# Epoch: 011, Loss: 3.707, Train RMSE: 1.797, Val RMSE: 2.347
# Epoch: 012, Loss: 4.662, Train RMSE: 1.358, Val RMSE: 2.596
# Epoch: 013, Loss: 3.543, Train RMSE: 1.119, Val RMSE: 3.096
# Epoch: 014, Loss: 4.216, Train RMSE: 1.118, Val RMSE: 3.025
# Epoch: 015, Loss: 3.998, Train RMSE: 1.401, Val RMSE: 2.560
# Epoch: 016, Loss: 3.600, Train RMSE: 1.660, Val RMSE: 2.403
# Epoch: 017, Loss: 4.202, Train RMSE: 1.316, Val RMSE: 2.634
# Epoch: 018, Loss: 3.504, Train RMSE: 1.119, Val RMSE: 3.018
# Epoch: 019, Loss: 3.978, Train RMSE: 1.138, Val RMSE: 2.910
# Epoch: 020, Loss: 3.716, Train RMSE: 1.432, Val RMSE: 2.536
# Epoch: 021, Loss: 3.652, Train RMSE: 1.540, Val RMSE: 2.466
# Epoch: 022, Loss: 3.877, Train RMSE: 1.226, Val RMSE: 2.737
# Epoch: 023, Loss: 3.493, Train RMSE: 1.123, Val RMSE: 2.976
# Epoch: 024, Loss: 3.867, Train RMSE: 1.210, Val RMSE: 2.761
# Epoch: 025, Loss: 3.507, Train RMSE: 1.477, Val RMSE: 2.505
# Epoch: 026, Loss: 3.736, Train RMSE: 1.395, Val RMSE: 2.565
# Epoch: 027, Loss: 3.592, Train RMSE: 1.164, Val RMSE: 2.843
# Epoch: 028, Loss: 3.599, Train RMSE: 1.149, Val RMSE: 2.878
# Epoch: 029, Loss: 3.655, Train RMSE: 1.330, Val RMSE: 2.621
# Epoch: 030, Loss: 3.515, Train RMSE: 1.442, Val RMSE: 2.529
# Epoch: 031, Loss: 3.669, Train RMSE: 1.246, Val RMSE: 2.712
# Epoch: 032, Loss: 3.484, Train RMSE: 1.151, Val RMSE: 2.873
# Epoch: 033, Loss: 3.646, Train RMSE: 1.242, Val RMSE: 2.717
# Epoch: 034, Loss: 3.485, Train RMSE: 1.406, Val RMSE: 2.556
# Epoch: 035, Loss: 3.608, Train RMSE: 1.308, Val RMSE: 2.642
# Epoch: 036, Loss: 3.498, Train RMSE: 1.173, Val RMSE: 2.824
# Epoch: 037, Loss: 3.572, Train RMSE: 1.208, Val RMSE: 2.764
# Epoch: 038, Loss: 3.510, Train RMSE: 1.357, Val RMSE: 2.596
# Epoch: 039, Loss: 3.542, Train RMSE: 1.332, Val RMSE: 2.619
# Epoch: 040, Loss: 3.517, Train RMSE: 1.198, Val RMSE: 2.779
# Epoch: 041, Loss: 3.522, Train RMSE: 1.201, Val RMSE: 2.775
# Epoch: 042, Loss: 3.518, Train RMSE: 1.323, Val RMSE: 2.628
# Epoch: 043, Loss: 3.509, Train RMSE: 1.332, Val RMSE: 2.619
# Epoch: 044, Loss: 3.517, Train RMSE: 1.217, Val RMSE: 2.751
# Epoch: 045, Loss: 3.501, Train RMSE: 1.205, Val RMSE: 2.768
# Epoch: 046, Loss: 3.513, Train RMSE: 1.305, Val RMSE: 2.646
# Epoch: 047, Loss: 3.496, Train RMSE: 1.322, Val RMSE: 2.629
# Epoch: 048, Loss: 3.508, Train RMSE: 1.226, Val RMSE: 2.738
# Epoch: 049, Loss: 3.493, Train RMSE: 1.214, Val RMSE: 2.755

# %%
def test(data):
    model.eval()
    pred = model(data.x_dict, data.edge_index_dict, data['user', 'movie'].edge_label_index)
    pred = pred.clamp(min=0, max=5)
    target = data['user', 'movie'].edge_label.float()
    rmse = F.mse_loss(pred, target).sqrt()
    return float(rmse), pred, target

# %%
test_rmse, test_pred, test_target = test(test_data)

# %%
from sklearn.metrics import precision_recall_fscore_support,accuracy_score

test_pred = test_pred.tolist()
test_target = test_target.tolist()
threshold = 3.5
pred_result = []
target_result = []

for i in range(len(test_pred)):
  if test_pred[i]>= threshold:
    pred_result.append(1)
  else:
    pred_result.append(0)

  if test_target[i]>= threshold:
    target_result.append(1)
  else:
    target_result.append(0)

roc_auc = roc_auc_score(target_result, pred_result)
accuracy = accuracy_score(target_result, pred_result)
matrix = precision_recall_fscore_support(target_result, pred_result, average='macro')

print(f'Test RMSE is: {test_rmse:03f}, ROC_AUC_Score: {roc_auc: 03f},  Accuracy: {accuracy: 03f}, Precision: {matrix[0]: 03f}, Recall: {matrix[1]: 03f}, F-Score: {matrix[2]: 03f}')
# Out:
# Test RMSE is: 2.754131, ROC_AUC_Score:  0.500000,  Accuracy:  0.720972, Precision:  0.360486, Recall:  0.500000, F-Score:  0.418933

# %% [markdown]
# # 5. Make a Recommendation

# %%
user_profile = {
    "UserID": 10,
    "Gender": "M",
    "Age": 25,
    "Occupation": 12,  # Programmer
    "Zip-code": "95136"
}

# %%
movie_profile = {
    "Release_Year_Range": [1975,2000],
    "Language": ["English"],
    "director": ["Steven Spielberg"],
    "Genre": ["Action","Horror"],
    "Star": ['roy scheider', 'robert shaw', 'richard dreyfuss', 'lorraine gary', 'murray hamilton', 'carl gottlieb', 'jeffrey kramer', 'susan backlinie', 'jonathan filley'],
    "Keywords": ['based on novel or book', 'beach', 'fishing', 'atlantic ocean', 'bathing', 'shipwreck', 'shark attack', 'police chief', 'ferry boat', 'dying and death', 'animal attack', 'long island, new york', 'dead child', 'creature', 'skinny dipping', 'shark', 'great white shark', 'dead dog', 'child killed by animal', 'fourth of july', 'severed leg', 'fishing boat', 'animal horror', 'shark cage']
}

# %%
def get_movie_recommendation(user_profile, movie_profile):
  num_movies = len(data['movie'].x)
  user_id = user_profile['UserID']
  movies_features = list(movies_df.columns)
  movie_mapping = {i: idx for i, idx in enumerate(movies_df.index)}

  row = torch.tensor([user_id] * num_movies)
  col = torch.arange(num_movies)
  edge_label_index = torch.stack([row, col], dim=0)

  pred = model(data.x_dict, data.edge_index_dict, edge_label_index)
  pred = pred.clamp(min=0, max=5)

  idx_max = torch.topk(pred, 50).indices
  # check if how many features each recommended movie align with user's preference
  movies = []
  preferred_movie_features = []
  for key in movie_profile.keys():
    if key != 'Release_Year_Range':
      for item in movie_profile[key]:
        preferred_movie_features.append(key+'_'+item)

  for i in idx_max:
    movie = {}
    movieId = movie_mapping[int(i)]
    movie['MovieID'] = movieId

    movie['title'] = movies_df.loc[movieId].title

    movie['satisfied_features'] = 0
    if movies_df.loc[movieId].Release_Year in movie_profile['Release_Year_Range']:
      movie['satisfied_features'] += 1

    for preferred_movie_feature in preferred_movie_features:
      if preferred_movie_feature in movies_features:
        if movies_df[preferred_movie_feature].loc[movieId] == True:
          movie['satisfied_features'] += 1

    movies.append(movie)

  #get top 5 movies
  top5_movies = sorted(movies, key=lambda d: d['satisfied_features'],reverse=True)[:5]
  print('Recommended movies for userId ' + str(user_id))
  for top_movie in top5_movies:
    print(top_movie['title'])

  return top5_movies

# %%
top5_movies = get_movie_recommendation(user_profile,movie_profile)
# Out:
# Recommended movies for userId 10
# Dead Presidents (1995)
# Sudden Death (1995)
# Mortal Kombat (1995)
# Get Shorty (1995)
# Heat (1995)

# %%
top5_movies
# Out:
# [{'MovieID': 41, 'title': 'Dead Presidents (1995)', 'satisfied_features': 2},
#  {'MovieID': 8, 'title': 'Sudden Death (1995)', 'satisfied_features': 2},
#  {'MovieID': 43, 'title': 'Mortal Kombat (1995)', 'satisfied_features': 2},
#  {'MovieID': 20, 'title': 'Get Shorty (1995)', 'satisfied_features': 2},
#  {'MovieID': 5, 'title': 'Heat (1995)', 'satisfied_features': 2}]
